# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
train=pd.read_csv('F:\mine\item demand forecasting/train.csv', parse_dates = ['date'])
train.head()
# Out:
#         date  store  item  sales
# 0 2013-01-01      1     1     13
# 1 2013-01-02      1     1     11
# 2 2013-01-03      1     1     14
# 3 2013-01-04      1     1     13
# 4 2013-01-05      1     1     10

# %%
train.describe()
# Out:
#                store           item          sales
# count  913000.000000  913000.000000  913000.000000
# mean        5.500000      25.500000      52.250287
# std         2.872283      14.430878      28.801144
# min         1.000000       1.000000       0.000000
# 25%         3.000000      13.000000      30.000000
# 50%         5.500000      25.500000      47.000000
# 75%         8.000000      38.000000      70.000000
# max        10.000000      50.000000     231.000000

# %%
test=pd.read_csv('F:\mine\item demand forecasting/test.csv', parse_dates = ['date'])
test.head()
# Out:
#    id       date  store  item
# 0   0 2018-01-01      1     1
# 1   1 2018-01-02      1     1
# 2   2 2018-01-03      1     1
# 3   3 2018-01-04      1     1
# 4   4 2018-01-05      1     1

# %%
train.set_index('date', inplace=True)
train.head()
# Out:
#             store  item  sales
# date
# 2013-01-01      1     1     13
# 2013-01-02      1     1     11
# 2013-01-03      1     1     14
# 2013-01-04      1     1     13
# 2013-01-05      1     1     10

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize = (12, 4))

sns.histplot(train['sales'], bins=20, ax=ax1)
ax1.set_title('Sales Distribution')
ax1.set_xlim(train['sales'].min())
sns.boxplot(train['sales'], ax=ax2 )

ax2.set_title('Sales Boxplot')
plt.tight_layout()
plt.show()

# %%
#outlier removing
train = train[train['sales'] < 
                    train['sales'].quantile(q = 0.98)]
train.describe()
# Out:
#                store           item          sales
# count  894353.000000  894353.000000  894353.000000
# mean        5.503875      25.539724      50.466051
# std         2.864735      14.490372      26.221418
# min         1.000000       1.000000       0.000000
# 25%         3.000000      13.000000      29.000000
# 50%         6.000000      26.000000      46.000000
# 75%         8.000000      38.000000      68.000000
# max        10.000000      50.000000     123.000000

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize = (16, 6))

sns.histplot(x=train['sales'], bins=20, ax=ax1, color='#369572')

ax1.set_title('Sales Distribution')
ax1.set_xlim(train['sales'].min())

sns.boxplot(train['sales'], ax=ax2, color='#369572')
ax2.set_title('Sales Boxplots')
plt.show()

# %%
# Autocorrelation Plot
from pandas.plotting import autocorrelation_plot
plt.figure(figsize=(12, 6))

autocorrelation_plot(train['sales'].values[:365])

plt.title('Autocorrelation Plot')
plt.grid()
plt.show()

# %%
import itertools
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import kpss
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
# Decompose the time series
plt.rcParams['figure.figsize'] = (12, 9)

result = seasonal_decompose(train['sales'].values[:30], 
                            model='additive', period=7)

# Plot the decomposition
result.plot()
plt.show()

# %%
def predict_sarimax(store, item):
    
    # Filter training data for the specific store and item
    target = train[(train['store'] == store) & (train['item'] == item)]

    # Fit SARIMAX model on training data
    model = sm.tsa.statespace.SARIMAX(target['sales'], order=(1, 1, 1), 
                                      seasonal_order=(1, 1, 1, 7)).fit(disp=False)

    # Use test data dates (first 3 months of 2018) to predict
    future_dates = test[(test['store'] == store) & (test['item'] == item)].index

    # Make predictions for future dates
    forecast = model.get_forecast(steps=len(future_dates))
    forecast_values = forecast.predicted_mean

    # Combine forecast with test data for future dates
    forecast_df = pd.DataFrame({'date': future_dates, 'forecast_sales': forecast_values})

    return forecast_df

# %%
# Example: Predict for store 1, item 1
results = pd.DataFrame()

print(f'Predicting for store {1} and item {1}')
sub_results = predict_sarimax(1, 1)

results = pd.concat([results, sub_results]).reset_index(drop=True)
results['date'] = test['date']

results
# Out:
# Predicting for store 1 and item 1
# F:\anaconda python\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# F:\anaconda python\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#          date  forecast_sales
# 0  2018-01-01       12.666370
# 1  2018-01-02       15.340930
# 2  2018-01-03       15.848827
# 3  2018-01-04       16.776035
# 4  2018-01-05       18.015356
# ..        ...             ...
# 85 2018-03-27       15.326301
# 86 2018-03-28       15.937051
# 87 2018-03-29       16.697908
# 88 2018-03-30       18.151233
# 89 2018-03-31       20.309441
#
# [90 rows x 2 columns]

# %%
results = pd.DataFrame()

print(f'Predicting for store {5} and item {5}')
sub_results = predict_sarimax(5, 5)

results = pd.concat([results, sub_results]).reset_index(drop=True)
results['date'] = test['date']

results
# Out:
# Predicting for store 5 and item 5
# F:\anaconda python\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# F:\anaconda python\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#          date  forecast_sales
# 0  2018-01-01        9.879214
# 1  2018-01-02       11.506950
# 2  2018-01-03       11.424138
# 3  2018-01-04       12.457545
# 4  2018-01-05       13.551324
# ..        ...             ...
# 85 2018-03-27       11.764594
# 86 2018-03-28       11.711018
# 87 2018-03-29       12.654018
# 88 2018-03-30       13.772329
# 89 2018-03-31       14.661604
#
# [90 rows x 2 columns]

# %%
# results = pd.DataFrame()

# for i in range(1, 51):
#   for j in range(1, 11):
#     print(f'Predicting for store {j} and item {i}')
#     sub_results = predict_sarimax(j, i)
#     results = pd.concat([results, sub_results]).reset_index(drop=True)
#     results['date'] = test['date']
#     print(results)

# %%
final_forecasts = pd.DataFrame(results)
final_forecasts
# Out:
#          date  forecast_sales
# 0  2018-01-01        9.879214
# 1  2018-01-02       11.506950
# 2  2018-01-03       11.424138
# 3  2018-01-04       12.457545
# 4  2018-01-05       13.551324
# ..        ...             ...
# 85 2018-03-27       11.764594
# 86 2018-03-28       11.711018
# 87 2018-03-29       12.654018
# 88 2018-03-30       13.772329
# 89 2018-03-31       14.661604
#
# [90 rows x 2 columns]

# %%
# Saving
# final_forecasts.to_csv('F:\mine\item demand forecasting\store_item_forecasts.csv', index=False)

# %%
# submission_df = test.loc[:, ['id']]
# submission_df["sales"] = final_forecasts['forecast_sales']
# submission_df
